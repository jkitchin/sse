# %% [markdown]
# OpenAlex
# ========
#
# [https://openalex.org/](https://openalex.org/) is an open catalog of the scientific literature. You can access information about papers, authors and more both through a browser, and via an API.
#
# # API
#
# An API is an Application Programming Interface. With OpenAlex, we specifically have a REST API which is an interface to exchange information over the internet using urls. Your browser does this all the time, and we will learn to do it in a shell today.
#
# The first step in using an API is to review it: [https://docs.openalex.org/how-to-use-the-api/api-overview](https://docs.openalex.org/how-to-use-the-api/api-overview)
#
# Note there are some Python libraries already, but we do not use these today.
#
# It is helpful to install a JsonViewer extension in your browser. I use [https://chrome.google.com/webstore/detail/jsonvue/chklaanhfefbnpoihckbnefhakgolnmc]().
#
# We start with the quickstart tutorial to get an idea of what is happening.
#
# [https://docs.openalex.org/quickstart-tutorial]()
#
# To use a REST API, we have to know how to construct a URL to an *endpoint* that will return data to us. These URLs have some pieces:
#
#     https://api.openalex.org/institutions is an endpoint for institutions
#
#     ?search=carnegie+mellon+university is a query for that endpoint
#
# We combine these to form a single URL: [https://api.openalex.org/institutions?search=carnegie+mellon+university](https://api.openalex.org/institutions?search=carnegie+mellon+university)

# %% [markdown]
# If you click on that url, you should see a web page of json data, it might resemble a dictionary in Python.

# %% [markdown]
# # JSON
#
# JSON stands for Javascript Object Notation. It is a standard data format for exchanging data. Most programming languages provide a library to parse and access this data, which makes it very convenient.

# %% [markdown]
# # Using REST APIs in the shell
#
# The goal today is not to use the browser. We will use it to help explore data, but with JSON data like this, the browser is not that useful to automate analysis, or for data extraction.
#
# ## Exploring the institutions endpoint
#
# In a shell, we use the `curl` command. Run this command in a shell:
#
#     curl https://api.openalex.org/institutions?search=carnegie+mellon+university

# %%
! curl https://api.openalex.org/institutions?search=carnegie+mellon+university
# Out:
# {"meta":{"count":4,"db_response_time_ms":137,"page":1,"per_page":25,"groups_count":null},"results":[{"id":"https://openalex.org/I74973139","ror":"https://ror.org/05x2bcf33","display_name":"Carnegie Mellon University","relevance_score":221112.05,"country_code":"US","type":"education","lineage":["https://openalex.org/I74973139"],"homepage_url":"http://www.cmu.edu/index.shtml","image_url":"https://upload.wikimedia.org/wikipedia/commons/1/1d/Www.wikipedia.org_screenshot_2018.png","image_thumbnail_url":"https://upload.wikimedia.org/wikipedia/commons/thumb/1/1d/Www.wikipedia.org_screenshot_2018.png/76px-Www.wikipedia.org_screenshot_2018.png","display_name_acronyms":["CMU"],"display_name_alternatives":[],"repositories":[{"id":"https://openalex.org/S4306400668","display_name":"Research Showcase @ Carnegie Mellon University (Carnegie Mellon University)","host_organization":"https://openalex.org/I74973139","host_organization_name":"Carnegie Mellon University","host_organization_lineage":["https://openalex.org/I74973139"]}],"works_count":121847,"cited_by_count":4971789,"summary_stats":{"2yr_mean_citedness":3.9174431202600215,"h_index":726,"i10_index":54178},"ids":{"openalex":"https://openalex.org/I74973139","ror":"https://ror.org/05x2bcf33","mag":"74973139","grid":"grid.147455.6","wikipedia":"https://en.wikipedia.org/wiki/Web%20server%20directory%20index","wikidata":"https://www.wikidata.org/wiki/Q2712836"},"geo":{"city":"Pittsburgh","geonames_city_id":"5206379","region":null,"country_code":"US","country":"United States","latitude":40.44062,"longitude":-79.99589},"international":{"display_name":{"ar":"\u0641\u0647\u0631\u0633 \u062f\u0644\u064a\u0644 \u062e\u0627\u062f\u0645 \u0627\u0644\u0648\u064a\u0628","cs":"Index","de":"Webserver Verzeichnis Index","el":"\u0395\u03c5\u03c1\u03b5\u03c4\u03ae\u03c1\u03b9\u03bf \u03ba\u03b1\u03c4\u03b1\u03bb\u03cc\u03b3\u03bf\u03c5 \u03b5\u03be\u03c5\u03c0\u03b7\u03c1\u03b5\u03c4\u03b7\u03c4\u03ae \u03b9\u03c3\u03c4\u03bf\u03cd","en":"webserver directory index","en-ca":"Web server directory index","en-gb":"Web server directory index","es":"\u00cdndice de un servidor web","fi":"Index.html","fr":"index de r\u00e9pertoire de serveur Web","it":"index","ja":"Web\u30b5\u30fc\u30d0\u30fc\u306e\u30a4\u30f3\u30c7\u30c3\u30af\u30b9\u30da\u30fc\u30b8","lv":"Web servera direktoriju indekss","pl":"Index","pt":"Index.html","pt-br":"Index.html","ru":"Index.htm","tr":"Web sunucusu dizin indeksi","uk":"\u0406\u043d\u0434\u0435\u043a\u0441 \u0434\u0438\u0440\u0435\u043a\u0442\u043e\u0440\u0456\u0457 \u0432\u0435\u0431-\u0441\u0435\u0440\u0432\u0435\u0440\u0430","zh":"\u7db2\u9801\u4f3a\u670d\u5668\u76ee\u9304\u7d22\u5f15","zh-cn":"\u7f51\u9875\u670d\u52a1\u5668\u76ee\u5f55\u7d22\u5f15","zh-hans":"\u7f51\u9875\u670d\u52a1\u5668\u76ee\u5f55\u7d22\u5f15","zh-hant":"\u7db2\u9801\u670d\u52d9\u5668\u76ee\u9304\u7d22\u5f15"}},"associated_institutions":[{"id":"https://openalex.org/I4210130200","ror":"https://ror.org/02f33m021","display_name":"Carnegie Mellon University Africa","country_code":"RW","type":"education","relationship":"child"},{"id":"https://openalex.org/I4210091826","ror":"https://ror.org/00ds41r10","display_name":"Carnegie Mellon University Australia","country_code":"AU","type":"education","relationship":"child"},{"id":"https://openalex.org/I4210089979","ror":"https://ror.org/00az5dt38","display_name":"Carnegie Mellon University Qatar","country_code":"QA","type":"education","relationship":"child"},{"id":"https://openalex.org/I4210086114","ror":"https://ror.org/00jfeg660","display_name":"Center for the Neural Basis of Cognition","country_code":"US","type":"facility","relationship":"child"},{"id":"https://openalex.org/I114772536","ror":"https://ror.org/01xqjjn94","display_name":"Software Engineering Institute","country_code":"US","type":"facility","relationship":"child"},{"id":"https://openalex.org/I4210129003","ror":"https://ror.org/02w30ae27","display_name":"SYSU-CMU International Joint Research Institute","countr ...

# %% [markdown]
# ```{note}
# Note the + in the search query. This is a common way to combine terms. It is usually undesireable to have spaces in the query, so they must either be escaped (usually by %20) or replaced (as in this case with +).
#
# It is also worth noting that by default curl and your browser are doing a GET request to the API. In this form, all data is sent to the API through the URL. There are other kinds of requests that are possible, such as  POST that allow you to send data in a different form. We don't cover that here.

# %% [markdown]
# The output is quite dense, and hard to look at. Let's select only a few items, and then pipe the output of that command into a python module that pretty-prints it:

# %%
! curl  "https://api.openalex.org/institutions?search=carnegie+mellon+university&select=id,display_name&email=jkitchin@cmu.edu"
# Out:
# {"meta":{"count":4,"db_response_time_ms":52,"page":1,"per_page":25,"groups_count":null},"results":[{"id":"https://openalex.org/I74973139","display_name":"Carnegie Mellon University"},{"id":"https://openalex.org/I4210089979","display_name":"Carnegie Mellon University Qatar"},{"id":"https://openalex.org/I4210091826","display_name":"Carnegie Mellon University Australia"},{"id":"https://openalex.org/I4210130200","display_name":"Carnegie Mellon University Africa"}],"group_by":[]}

# %% [markdown]
# It is important to note that now we have requested the same information twice, and we still haven't done anything with it. To avoid this, let's request it one more time, and redirect the output into a file for further analysis. Since we do that in the notebook, the file gets saved in the current working directory.

# %%
! pwd
! curl -s https://api.openalex.org/institutions?search=carnegie+mellon+university > cmu.json
# Out:
# /home/jupyter-jkitchin@andrew.cm-11dd7/s24-06643/sse/01-rest-api-openalex

# %% [markdown]
#
# Now, we can check the contents of that file to make sure we have the right thing:

# %%
! cat cmu.json | python -m json.tool
# Out:
# {
#     "meta": {
#         "count": 4,
#         "db_response_time_ms": 137,
#         "page": 1,
#         "per_page": 25,
#         "groups_count": null
#     },
#     "results": [
#         {
#             "id": "https://openalex.org/I74973139",
#             "ror": "https://ror.org/05x2bcf33",
#             "display_name": "Carnegie Mellon University",
#             "relevance_score": 221112.05,
#             "country_code": "US",
#             "type": "education",
#             "lineage": [
#                 "https://openalex.org/I74973139"
#             ],
#             "homepage_url": "http://www.cmu.edu/index.shtml",
#             "image_url": "https://upload.wikimedia.org/wikipedia/commons/1/1d/Www.wikipedia.org_screenshot_2018.png",
#             "image_thumbnail_url": "https://upload.wikimedia.org/wikipedia/commons/thumb/1/1d/Www.wikipedia.org_screenshot_2018.png/76px-Www.wikipedia.org_screenshot_2018.png",
#             "display_name_acronyms": [
#                 "CMU"
#             ],
#             "display_name_alternatives": [],
#             "repositories": [
#                 {
#                     "id": "https://openalex.org/S4306400668",
#                     "display_name": "Research Showcase @ Carnegie Mellon University (Carnegie Mellon University)",
#                     "host_organization": "https://openalex.org/I74973139",
#                     "host_organization_name": "Carnegie Mellon University",
#                     "host_organization_lineage": [
#                         "https://openalex.org/I74973139"
#                     ]
#                 }
#             ],
#             "works_count": 121847,
#             "cited_by_count": 4971789,
#             "summary_stats": {
#                 "2yr_mean_citedness": 3.9174431202600215,
#                 "h_index": 726,
#                 "i10_index": 54178
#             },
#             "ids": {
#                 "openalex": "https://openalex.org/I74973139",
#                 "ror": "https://ror.org/05x2bcf33",
#                 "mag": "74973139",
#                 "grid": "grid.147455.6",
#                 "wikipedia": "https://en.wikipedia.org/wiki/Web%20server%20directory%20index",
#                 "wikidata": "https://www.wikidata.org/wiki/Q2712836"
#             },
#             "geo": {
#                 "city": "Pittsburgh",
#                 "geonames_city_id": "5206379",
#                 "region": null,
#                 "country_code": "US",
#                 "country": "United States",
#                 "latitude": 40.44062,
#                 "longitude": -79.99589
#             },
#             "international": {
#                 "display_name": {
#                     "ar": "\u0641\u0647\u0631\u0633 \u062f\u0644\u064a\u0644 \u062e\u0627\u062f\u0645 \u0627\u0644\u0648\u064a\u0628",
#                     "cs": "Index",
#                     "de": "Webserver Verzeichnis Index",
#                     "el": "\u0395\u03c5\u03c1\u03b5\u03c4\u03ae\u03c1\u03b9\u03bf \u03ba\u03b1\u03c4\u03b1\u03bb\u03cc\u03b3\u03bf\u03c5 \u03b5\u03be\u03c5\u03c0\u03b7\u03c1\u03b5\u03c4\u03b7\u03c4\u03ae \u03b9\u03c3\u03c4\u03bf\u03cd",
#                     "en": "webserver directory index",
#                     "en-ca": "Web server directory index",
#                     "en-gb": "Web server directory index",
#                     "es": "\u00cdndice de un servidor web",
#                     "fi": "Index.html",
#                     "fr": "index de r\u00e9pertoire de serveur Web",
#                     "it": "index",
#                     "ja": "Web\u30b5\u30fc\u30d0\u30fc\u306e\u30a4\u30f3\u30c7\u30c3\u30af\u30b9\u30da\u30fc\u30b8",
#                     "lv": "Web servera direktoriju indekss",
#                     "pl": "Index",
#                     "pt": "Index.html",
#                     "pt-br": "Index.html",
#                     "ru": "Index.htm",
#                     "tr": "Web sunucusu dizin indeksi",
#                     "uk": "\u0406\u043d\u0434\u0435\u043a\u0441 \u0434\u0438\u0440\u0435\u043a\u0442\u043e\u0440\u0456\u0457 \u0432\u0435\u0431-\u0441\u0435\u0440\u0432\u0435\u0440\u0430",
#                     "zh": "\u7db2\u9801\u4f3a\u670d\u5668\u76ee\u9304\u7d22\u5f15",
#                     "zh-cn": "\u7f51\u9875\u670d\u52a1\u5668\u76ee\u5f55\u7d22\u5f15",
#                     "zh-hans": "\u7f51\u9875\u670d\u52a1\u5668\u76ee\u5f55\u7d22\u5f15",
#                     "zh-hant": "\u7db2\u9801\u670d\u52d9\u5668\u76ee\u9304\u7d22\u5f15"
#                 }
#             },
#             "associated_institutions": [
#                 {
#                     "id": "https://openalex.org/I4210130200",
#                     "ror": "https://ror.org/02f33m021",
#                     "display_name": "Carnegie Mellon University Africa",
#                     "country_code": "RW",
#                     "type": "education",
#                     "relationship": "child"
#                 },
#                 {
#                     "id": "https://openalex.org/I4210091826",
#                     "ror": "https://ror.org/00ds41r10",
#                     "display_name": "Carnegie Mellon University Australia",
#                     "country_code": "AU",
#                     "type": "education",
#                     "relationship": "child"
#                 },
#                 {
#                     "id": "https://openalex.org/I4210089979",
#                     "ror": "https://ror.org/00az5dt38",
#                     "display_name": "Carnegie Mellon University Qatar",
#                     "country_code": "QA",
#                     "type": "education",
#                     "relationship": "child"
#                 },
#                 {
#                     "id": "https://openalex.org/I4210086114",
#                     "ror": "https://ror.org/00jfeg660",
#                     "display_name": "Center for the Neural Basis of Cognition",
#                     "country_code": "US",
#                     "type": "facility",
#                     "relationship": "child"
#                 },
#                 {
#                     "id": "https://openalex.org/I114772536",
#                     "ror": "https://ror.org/01xqjjn94",
#                     "display_name": "Software Engineering Institute",
#                     "country_code": "US",
#                     "type": "facility",
#                     "relationship": "child"
#                 },
#                 {
#                     "id": "https://openalex.org/I4210129003",
#                     "ror": "https://ror.org/02w30ae27",
#                     "display_name": "SYSU-CMU International Joint Research Institute",
#                     "country_code": "CN",
#                     "type": "facility",
#                     "relationship": "related"
#                 },
#                 {
#                     "id": "https://openalex.org/I4210128526",
#                     "ror": "https://ror.org/03bw34a45",
#                     "display_name": "UPMC Hillman Cancer Center",
#                     "country_code": "US",
#                     "type": "facility",
#                     "relationship": "related"
#                 }
#             ],
#             "counts_by_year": [
#                 {
#                     "year": 2024,
#                     "works_count": 672,
#                     "cited_by_count": 55201
#                 },
#                 {
#                     "year": 2023,
#                     "works_count": 4165,
#                     "cited_by_count": 303313
#                 },
#                 {
#                     "year": 2022,
#                     "works_count": 4029,
#                     "cited_by_count": 304660
#                 },
#                 {
#                     "year": 2021,
#                     "works_count": 5244,
#                     "cited_by_count": 359260
#                 },
#                 {
#                     "year": 2020,
#                     "works_count": 5269,
#                     "cited_by_count": 334249
#                 },
#                 {
#                     "year": 2019,
#                     "works_count": 5147,
#                     "cited_by_count": 299847
#                 },
#                 {
#                     "year": 2018,
#                     "works_count": 4818,
#                     "cited_by_count": 265101
#                 },
#                 {
#                     "year": 2017,
#                     "works_count": 4519,
#                     "cited_by_count": 239252
#                 },
#                 {
#                     "year": 2016,
#                     "works_count": 4355,
#                     "cited_by_count": 234293
#                 },
#                 {
#                     "year": 2015,
#                     "works_count": 4479,
#                     "cited_by_count": 235068
#                 },
#                 {
#                     "year": 2014,
#                     "works_count": 4249,
#                     "cited_by_count": 224844
#                 },
#                 {
#                     "year": 2013,
#                     "works_count": 4216,
#                     "cited_by_count": 207978
#                 },
#                 {
#                     "year": 2012,
#                     "works_count": 4121,
#                     "cited_by_count": 195200
#                 }
#             ],
#             "roles": [
#                 {
#                     "role": "institution",
#                     "id": "https://openalex.org/I74973139",
#                     "works_count": 121847
#                 },
#                 {
#                     "role": "funder",
#                     "id": "https://openalex.org/F4320310207",
#                     "works_count": 1000
#                 }
#             ],
#             "x_concepts": [
#                 {
#                     "id": "https://openalex.org/C41008148",
#                     "wikidata": "https://www.wikidata.org/wiki/Q21198",
#                     "display_name": "Computer science",
#                     "level": 0,
#                     "score": 74.3
#                 },
#                 {
#                     "id": "https://openalex.org/C33923547",
#                     "wikidata": "https://www.wikidata.org/wiki/Q395",
#                     "display_name": "Mathematics",
#                     "level": 0,
#                     "score": 53.0
#                 },
#                 {
#                     "id": "https://openalex.org/C121332964",
#                     "wikidata": "https://www.wikidata.org/wiki/Q413",
#                     "display_name": "Physics",
#                     "level": 0,
#                     "score": 51.9
#                 },
#                 {
#                     "id": "https://openalex.org/C127413603",
#                     "wikidata": "https://www.wikidata.org/wiki/Q11023",
#                     "display_name": "Engineering",
#                     "level": 0,
#                     "score": 49.7
#                 },
#                 {
#                     "id": "https://openalex.org/C86803240",
#                     "wikidata": "https://www.wikidata.org/wiki/Q420",
#                     "display_name": "Biology",
#                     "level": 0,
#                     "score": 40.3
#                 },
#                 {
#                     "id": "https://openalex.org/C154945302",
#                     "wikidata": "https://www.wikidata.org/wiki/Q11660",
#                     "display_name": "Artificial intelligence",
#                     "level": 1,
#                     "score": 37.9
#                 },
#                 {
#                     "id": "https://openalex.org/C62520636",
#                     "wikidata": "https://www.wikidata.org/wiki/Q944",
#                     "display_name": "Quantum mechanics",
#                     "level": 1,
#                     "score": 37.5
#                 },
#                 {
#                     "id": "https://openalex.org/C199360897",
#                     "wikidata": "https://www.wikidata.org/wiki/Q9143",
#                     "display_name": "Programming language",
#                     "level": 1,
#                     "score": 30.4
#                 },
#                 {
#                     "id": "https://openalex.org/C185592680",
#                     "wikidata": "https://www.wikidata.org/wiki/Q2329",
#                     "display_name": "Chemistry",
#                     "level": 0,
#                     "score": 29.5
#                 },
#                 {
#                     "id": "https://openalex.org/C138885662",
#                     "wikidata": "https://www.wikidata.org/wiki/Q5891",
#                     "display_name": "Philosophy",
#                     "level": 0,
#                     "score": 29.2
#                 },
#                 {
#                     "id": "https://openalex.org/C111919701",
#                     "wikidata": "https://www.wikidata.org/wiki/Q9135",
#                     "display_name": "Operating system",
#                     "level": 1,
#                     "score": 28.7
#                 },
#                 {
#                     "id": "https://openalex.org/C162324750",
#                     "wikidata": "https://www.wikidata.org/wiki/Q8134",
#                     "display_name": "Economics",
#                     "level": 0,
#                     "score": 28.6
#                 },
#                 {
#                     "id": "https://openalex.org/C15744967",
#                     "wikidata": "https://www.wikidata.org/wiki/Q9418",
#                     "display_name": "Psychology",
#                     "level": 0,
#                     "score": 24.5
#                 },
#                 {
#                     "id": "https://openalex.org/C192562407",
#                     "wikidata": "https://www.wikidata.org/wiki/Q228736",
#                     "display_name": "Materials science",
#                     "level": 0,
#                     "score": 23.3
#                 },
#                 {
#                     "id": "https://openalex.org/C105795698",
#                     "wikidata": "https://www.wikidata.org/wiki/Q12483",
#                     "display_name": "Statistics",
#                     "level": 1,
#                     "score": 22.3
#                 },
#                 {
#                     "id": "https://openalex.org/C71924100",
#                     "wikidata": "https://www.wikidata.org/wiki/Q11190",
#                     "display_name": "Medicine",
#                     "level": 0,
#                     "score": 21.0
#                 },
#                 {
#                     "id": "https://openalex.org/C17744445",
#                     "wikidata": "https://www.wikidata.org/wiki/Q36442",
#                     "display_name": "Political science",
#                     "level": 0,
#                     "score": 20.3
#                 }
#             ],
#             "works_api_url": "https://api.openalex.org/works?filter=institutions.id:I74973139",
#             "updated_date": "2024-03-13T08:41:21.607048",
#             "created_date": "2016-06-24"
#         },
#         {
#             "id": "https://openalex.org/I4210089979",
#             "ror": "https://ror.org/00az5dt38",
#             "display_name": "Carnegie Mellon University Qatar",
#             "relevance_score": 8878.564,
#             "country_code": "QA",
#             "type": "education",
#             "lineage": [
#                 "https://openalex.org/I4210089979",
#                 "https://openalex.org/I74973139"
#             ],
#             "homepage_url": "http://www.qatar.cmu.edu/",
#             "image_url": "https://upload.wikimedia.org/wikipedia/en/b/bc/Carnegiemellonqatar_building_entrance.jpg",
#             "image_thumbnail_url": "https://upload.wikimedia.org/wikipedia/en/thumb/b/bc/Carnegiemellonqatar_building_entrance.jpg/100px-Carnegiemellonqatar_building_entrance.jpg",
#             "display_name_acronyms": [
#                 "CMU-Q"
#             ],
#             "display_name_alternatives": [],
#             "repositories": [],
#             "works_count": 697,
#             "cited_by_count": 9734,
#             "summary_stats": {
#                 "2yr_mean_citedness": 3.4615384615384617,
#                 "h_index": 48,
#                 "i10_index": 192
#             },
#             "ids": {
#                 "openalex": "https://openalex.org/I4210089979",
#                 "ror": "https://ror.org/00az5dt38",
#                 "grid": "grid.452171.4",
#                 "wikipedia": "https://en.wikipedia.org/wiki/Carnegie%20Mellon%20University%20in%20Qatar"
#             },
#             "geo": {
#                 "city": "Doha",
#                 "geonames_city_id": "290030",
#                 "region": null,
#                 "country_code": "QA",
#                 "country": "Qatar",
#                 "latitude": 25.31639,
#                 "longitude": 51.43889
#             },
#             "international": {
#                 "display_name": {
#                     "en": "Carnegie Mellon University Qatar"
#                 }
#             },
#             "associated_institutions": [
#                 {
#                     "id": "https://openalex.org/I74973139",
#                     "ror": "https://ror.org/05x2bcf33",
#                     "display_name": "Carnegie Mellon University",
#                     "country_code": "US",
#                     "type": "education",
#                     "relationship": "parent"
#                 }
#             ],
#             "counts_by_year": [
#                 {
#                     "year": 2024,
#                     "works_count": 12,
#                     "cited_by_count": 211
#                 },
#                 {
#                     "year": 2023,
#                     "works_count": 35,
#                     "cited_by_count": 1186
#                 },
#                 {
#                     "year": 2022,
#                     "works_count": 23,
#                     "cited_by_count": 1160
#                 },
#                 {
#                     "year": 2021,
#                     "works_count": 45,
#                     "cited_by_count": 1296
#                 },
#                 {
#                     "year": 2020,
#                     "works_count": 38,
#                     "cited_by_count": 1047
#                 },
#                 {
#                     "year": 2019,
#                     "works_count": 36,
#                     "cited_by_count": 948
#                 },
#                 {
#                     "year": 2018,
#                     "works_count": 67,
#                     "cited_by_count": 641
#                 },
#                 {
#                     "year": 2017,
#                     "works_count": 28,
#                     "cited_by_count": 577
#                 },
#                 {
#                     "year": 2016,
#                     "works_count": 49,
#                     "cited_by_count": 521
#                 },
#                 {
#                     "year": 2015,
#                     "works_count": 38,
#                     "cited_by_count": 518
#                 },
#                 {
#                     "year": 2014,
#                     "works_count": 52,
#                     "cited_by_count": 406
#                 },
#                 {
#                     "year": 2013,
#                     "works_count": 68,
#                     "cited_by_count": 331
#                 },
#                 {
#                     "year": 2012,
#                     "works_count": 41,
#                     "cited_by_count": 254
#                 }
#             ],
#             "roles": [
#                 {
#                     "role": "institution",
#                     "id": "https://openalex.org/I4210089979",
#                     "works_count": 697
#                 }
#             ],
#             "x_concepts": [
#                 {
#                     "id": "https://openalex.org/C41008148",
#                     "wikidata": "https://www.wikidata.org/wiki/Q21198",
#                     "display_name": "Computer science",
#                     "level": 0,
#                     "score": 79.9
#                 },
#                 {
#                     "id": "https://openalex.org/C33923547",
#                     "wikidata": "https://www.wikidata.org/wiki/Q395",
#                     "display_name": "Mathematics",
#                     "level": 0,
#                     "score": 51.2
#                 },
#                 {
#                     "id": "https://openalex.org/C127413603",
#                     "wikidata": "https://www.wikidata.org/wiki/Q11023",
#                     "display_name": "Engineering",
#                     "level": 0,
#                     "score": 47.6
#                 },
#                 {
#                     "id": "https://openalex.org/C86803240",
#                     "wikidata": "https://www.wikidata.org/wiki/Q420",
#                     "display_name": "Biology",
#                     "level": 0,
#                     "score": 43.2
#                 },
#                 {
#                     "id": "https://openalex.org/C138885662",
#                     "wikidata": "https://www.wikidata.org/wiki/Q5891",
#                     "display_name": "Philosophy",
#                     "level": 0,
#                     "score": 42.0
#                 },
#                 {
#                     "id": "https://openalex.org/C154945302",
#                     "wikidata": "https://www.wikidata.org/wiki/Q11660",
#                     "display_name": "Artificial intelligence",
#                     "level": 1,
#                     "score": 38.7
#                 },
#                 {
#                     "id": "https://openalex.org/C17744445",
#                     "wikidata": "https://www.wikidata.org/wiki/Q36442",
#                     "display_name": "Political science",
#                     "level": 0,
#                     "score": 37.3
#                 },
#                 {
#                     "id": "https://openalex.org/C199539241",
#                     "wikidata": "https://www.wikidata.org/wiki/Q7748",
#                     "display_name": "Law",
#                     "level": 1,
#                     "score": 36.3
#                 },
#                 {
#                     "id": "https://openalex.org/C121332964",
#                     "wikidata": "https://www.wikidata.org/wiki/Q413",
#                     "display_name": "Physics",
#                     "level": 0,
#                     "score": 35.9
#                 },
#                 {
#                     "id": "https://openalex.org/C111919701",
#                     "wikidata": "https://www.wikidata.org/wiki/Q9135",
#                     "display_name": "Operating system",
#                     "level": 1,
#                     "score": 35.2
#                 },
#                 {
#                     "id": "https://openalex.org/C162324750",
#                     "wikidata": "https://www.wikidata.org/wiki/Q8134",
#                     "display_name": "Economics",
#                     "level": 0,
#                     "score": 31.6
#                 },
#                 {
#                     "id": "https://openalex.org/C199360897",
#                     "wikidata": "https://www.wikidata.org/wiki/Q9143",
#                     "display_name": "Programming language",
#                     "level": 1,
#                     "score": 31.1
#                 },
#                 {
#                     "id": "https://openalex.org/C15744967",
#                     "wikidata": "https://www.wikidata.org/wiki/Q9418",
#                     "display_name": "Psychology",
#                     "level": 0,
#                     "score": 30.7
#                 },
#                 {
#                     "id": "https://openalex.org/C41895202",
#                     "wikidata": "https://www.wikidata.org/wiki/Q8162",
#                     "display_name": "Linguistics",
#                     "level": 1,
#                     "score": 30.4
#                 },
#                 {
#                     "id": "https://openalex.org/C205649164",
#                     "wikidata": "https://www.wikidata.org/wiki/Q1071",
#                     "display_name": "Geography",
#                     "level": 0,
#                     "score": 26.3
#                 },
#                 {
#                     "id": "https://openalex.org/C71924100",
#                     "wikidata": "https://www.wikidata.org/wiki/Q11190",
#                     "display_name": "Medicine",
#                     "level": 0,
#                     "score": 25.5
#                 },
#                 {
#                     "id": "https://openalex.org/C62520636",
#                     "wikidata": "https://www.wikidata.org/wiki/Q944",
#                     "display_name": "Quantum mechanics",
#                     "level": 1,
#                     "score": 25.0
#                 },
#                 {
#                     "id": "https://openalex.org/C144024400",
#                     "wikidata": "https://www.wikidata.org/wiki/Q21201",
#                     "display_name": "Sociology",
#                     "level": 0,
#                     "score": 23.5
#                 }
#             ],
#             "works_api_url": "https://api.openalex.org/works?filter=institutions.id:I4210089979",
#             "updated_date": "2024-03-13T09:28:29.553553",
#             "created_date": "2022-02-02"
#         },
#         {
#             "id": "https://openalex.org/I4210091826",
#             "ror": "https://ror.org/00ds41r10",
#             "display_name": "Carnegie Mellon University Australia",
#             "relevance_score": 4259.112,
#             "country_code": "AU",
#             "type": "education",
#             "lineage": [
#                 "https://openalex.org/I4210091826",
#                 "https://openalex.org/I74973139"
#             ],
#             "homepage_url": "https://www.australia.cmu.edu/",
#             "image_url": "https://upload.wikimedia.org/wikipedia/commons/4/41/Torrens_Building%2C_Wakefield_St%2C_Adelaide.JPG",
#             "image_thumbnail_url": "https://upload.wikimedia.org/wikipedia/commons/thumb/4/41/Torrens_Building%2C_Wakefield_St%2C_Adelaide.JPG/100px-Torrens_Building%2C_Wakefield_St%2C_Adelaide.JPG",
#             "display_name_acronyms": [
#                 "CMU"
#             ],
#             "display_name_alternatives": [],
#             "repositories": [],
#             "works_count": 93,
#             "cited_by_count": 2191,
#             "summary_stats": {
#                 "2yr_mean_citedness": 2.0,
#                 "h_index": 11,
#                 "i10_index": 13
#             },
#             "ids": {
#                 "openalex": "https://openalex.org/I4210091826",
#                 "ror": "https://ror.org/00ds41r10",
#                 "grid": "grid.448660.8",
#                 "wikipedia": "https://en.wikipedia.org/wiki/Carnegie%20Mellon%20University%2C%20Australia"
#             },
#             "geo": {
#                 "city": "Adelaide",
#                 "geonames_city_id": "2078025",
#                 "region": "South Australia",
#                 "country_code": "AU",
#                 "country": "Australia",
#                 "latitude": 40.44285,
#                 "longitude": -79.94308
#             },
#             "international": {
#                 "display_name": {
#                     "en": "Carnegie Mellon University Australia"
#                 }
#             },
#             "associated_institutions": [
#                 {
#                     "id": "https://openalex.org/I74973139",
#                     "ror": "https://ror.org/05x2bcf33",
#                     "display_name": "Carnegie Mellon University",
#                     "country_code": "US",
#                     "type": "education",
#                     "relationship": "parent"
#                 }
#             ],
#             "counts_by_year": [
#                 {
#                     "year": 2024,
#                     "works_count": 0,
#                     "cited_by_count": 9
#                 },
#                 {
#                     "year": 2023,
#                     "works_count": 0,
#                     "cited_by_count": 86
#                 },
#                 {
#                     "year": 2022,
#                     "works_count": 1,
#                     "cited_by_count": 77
#                 },
#                 {
#                     "year": 2021,
#                     "works_count": 5,
#                     "cited_by_count": 74
#                 },
#                 {
#                     "year": 2020,
#                     "works_count": 7,
#                     "cited_by_count": 59
#                 },
#                 {
#                     "year": 2019,
#                     "works_count": 16,
#                     "cited_by_count": 50
#                 },
#                 {
#                     "year": 2018,
#                     "works_count": 1,
#                     "cited_by_count": 51
#                 },
#                 {
#                     "year": 2017,
#                     "works_count": 2,
#                     "cited_by_count": 35
#                 },
#                 {
#                     "year": 2016,
#                     "works_count": 19,
#                     "cited_by_count": 43
#                 },
#                 {
#                     "year": 2015,
#                     "works_count": 1,
#                     "cited_by_count": 31
#                 },
#                 {
#                     "year": 2014,
#                     "works_count": 2,
#                     "cited_by_count": 45
#                 },
#                 {
#                     "year": 2013,
#                     "works_count": 0,
#                     "cited_by_count": 55
#                 },
#                 {
#                     "year": 2012,
#                     "works_count": 12,
#                     "cited_by_count": 59
#                 }
#             ],
#             "roles": [
#                 {
#                     "role": "institution",
#                     "id": "https://openalex.org/I4210091826",
#                     "works_count": 93
#                 }
#             ],
#             "x_concepts": [
#                 {
#                     "id": "https://openalex.org/C41008148",
#                     "wikidata": "https://www.wikidata.org/wiki/Q21198",
#                     "display_name": "Computer science",
#                     "level": 0,
#                     "score": 89.2
#                 },
#                 {
#                     "id": "https://openalex.org/C127413603",
#                     "wikidata": "https://www.wikidata.org/wiki/Q11023",
#                     "display_name": "Engineering",
#                     "level": 0,
#                     "score": 47.3
#                 },
#                 {
#                     "id": "https://openalex.org/C17744445",
#                     "wikidata": "https://www.wikidata.org/wiki/Q36442",
#                     "display_name": "Political science",
#                     "level": 0,
#                     "score": 47.3
#                 },
#                 {
#                     "id": "https://openalex.org/C199539241",
#                     "wikidata": "https://www.wikidata.org/wiki/Q7748",
#                     "display_name": "Law",
#                     "level": 1,
#                     "score": 47.3
#                 },
#                 {
#                     "id": "https://openalex.org/C111919701",
#                     "wikidata": "https://www.wikidata.org/wiki/Q9135",
#                     "display_name": "Operating system",
#                     "level": 1,
#                     "score": 47.3
#                 },
#                 {
#                     "id": "https://openalex.org/C33923547",
#                     "wikidata": "https://www.wikidata.org/wiki/Q395",
#                     "display_name": "Mathematics",
#                     "level": 0,
#                     "score": 44.1
#                 },
#                 {
#                     "id": "https://openalex.org/C199360897",
#                     "wikidata": "https://www.wikidata.org/wiki/Q9143",
#                     "display_name": "Programming language",
#                     "level": 1,
#                     "score": 43.0
#                 },
#                 {
#                     "id": "https://openalex.org/C144133560",
#                     "wikidata": "https://www.wikidata.org/wiki/Q4830453",
#                     "display_name": "Business",
#                     "level": 0,
#                     "score": 38.7
#                 },
#                 {
#                     "id": "https://openalex.org/C162324750",
#                     "wikidata": "https://www.wikidata.org/wiki/Q8134",
#                     "display_name": "Economics",
#                     "level": 0,
#                     "score": 37.6
#                 },
#                 {
#                     "id": "https://openalex.org/C138885662",
#                     "wikidata": "https://www.wikidata.org/wiki/Q5891",
#                     "display_name": "Philosophy",
#                     "level": 0,
#                     "score": 33.3
#                 },
#                 {
#                     "id": "https://openalex.org/C95457728",
#                     "wikidata": "https://www.wikidata.org/wiki/Q309",
#                     "display_name": "History",
#                     "level": 0,
#                     "score": 29.0
#                 },
#                 {
#                     "id": "https://openalex.org/C205649164",
#                     "wikidata": "https://www.wikidata.org/wiki/Q1071",
#                     "display_name": "Geography",
#                     "level": 0,
#                     "score": 26.9
#                 },
#                 {
#                     "id": "https://openalex.org/C136764020",
#                     "wikidata": "https://www.wikidata.org/wiki/Q466",
#                     "display_name": "World Wide Web",
#                     "level": 1,
#                     "score": 25.8
#                 },
#                 {
#                     "id": "https://openalex.org/C166957645",
#                     "wikidata": "https://www.wikidata.org/wiki/Q23498",
#                     "display_name": "Archaeology",
#                     "level": 1,
#                     "score": 24.7
#                 },
#                 {
#                     "id": "https://openalex.org/C121332964",
#                     "wikidata": "https://www.wikidata.org/wiki/Q413",
#                     "display_name": "Physics",
#                     "level": 0,
#                     "score": 23.7
#                 },
#                 {
#                     "id": "https://openalex.org/C86803240",
#                     "wikidata": "https://www.wikidata.org/wiki/Q420",
#                     "display_name": "Biology",
#                     "level": 0,
#                     "score": 23.7
#                 },
#                 {
#                     "id": "https://openalex.org/C71924100",
#                     "wikidata": "https://www.wikidata.org/wiki/Q11190",
#                     "display_name": "Medicine",
#                     "level": 0,
#                     "score": 22.6
#                 },
#                 {
#                     "id": "https://openalex.org/C142362112",
#                     "wikidata": "https://www.wikidata.org/wiki/Q735",
#                     "display_name": "Art",
#                     "level": 0,
#                     "score": 21.5
#                 },
#                 {
#                     "id": "https://openalex.org/C154945302",
#                     "wikidata": "https://www.wikidata.org/wiki/Q11660",
#                     "display_name": "Artificial intelligence",
#                     "level": 1,
#                     "score": 21.5
#                 },
#                 {
#                     "id": "https://openalex.org/C11413529",
#                     "wikidata": "https://www.wikidata.org/wiki/Q8366",
#                     "display_name": "Algorithm",
#                     "level": 1,
#                     "score": 20.4
#                 },
#                 {
#                     "id": "https://openalex.org/C105795698",
#                     "wikidata": "https://www.wikidata.org/wiki/Q12483",
#                     "display_name": "Statistics",
#                     "level": 1,
#                     "score": 20.4
#                 },
#                 {
#                     "id": "https://openalex.org/C41895202",
#                     "wikidata": "https://www.wikidata.org/wiki/Q8162",
#                     "display_name": "Linguistics",
#                     "level": 1,
#                     "score": 20.4
#                 }
#             ],
#             "works_api_url": "https://api.openalex.org/works?filter=institutions.id:I4210091826",
#             "updated_date": "2024-03-11T12:13:49.647758",
#             "created_date": "2022-02-02"
#         },
#         {
#             "id": "https://openalex.org/I4210130200",
#             "ror": "https://ror.org/02f33m021",
#             "display_name": "Carnegie Mellon University Africa",
#             "relevance_score": 3133.7476,
#             "country_code": "RW",
#             "type": "education",
#             "lineage": [
#                 "https://openalex.org/I4210130200",
#                 "https://openalex.org/I74973139"
#             ],
#             "homepage_url": "https://www.africa.engineering.cmu.edu/",
#             "image_url": "https://upload.wikimedia.org/wikipedia/en/b/bb/Carnegie_Mellon_University_seal.svg",
#             "image_thumbnail_url": "https://upload.wikimedia.org/wikipedia/en/thumb/b/bb/Carnegie_Mellon_University_seal.svg/100px-Carnegie_Mellon_University_seal.svg.png",
#             "display_name_acronyms": [
#                 "CMU"
#             ],
#             "display_name_alternatives": [],
#             "repositories": [],
#             "works_count": 187,
#             "cited_by_count": 1168,
#             "summary_stats": {
#                 "2yr_mean_citedness": 3.396551724137931,
#                 "h_index": 18,
#                 "i10_index": 27
#             },
#             "ids": {
#                 "openalex": "https://openalex.org/I4210130200",
#                 "ror": "https://ror.org/02f33m021",
#                 "grid": "grid.508475.b",
#                 "wikipedia": "https://en.wikipedia.org/wiki/Carnegie%20Mellon%20University"
#             },
#             "geo": {
#                 "city": "Kigali",
#                 "geonames_city_id": "202061",
#                 "region": null,
#                 "country_code": "RW",
#                 "country": "Rwanda",
#                 "latitude": -1.935111,
#                 "longitude": 30.158602
#             },
#             "international": {
#                 "display_name": {
#                     "en": "Carnegie Mellon University Africa"
#                 }
#             },
#             "associated_institutions": [
#                 {
#                     "id": "https://openalex.org/I74973139",
#                     "ror": "https://ror.org/05x2bcf33",
#                     "display_name": "Carnegie Mellon University",
#                     "country_code": "US",
#                     "type": "education",
#                     "relationship": "parent"
#                 }
#             ],
#             "counts_by_year": [
#                 {
#                     "year": 2024,
#                     "works_count": 3,
#                     "cited_by_count": 66
#                 },
#                 {
#                     "year": 2023,
#                     "works_count": 48,
#                     "cited_by_count": 391
#                 },
#                 {
#                     "year": 2022,
#                     "works_count": 30,
#                     "cited_by_count": 242
#                 },
#                 {
#                     "year": 2021,
#                     "works_count": 28,
#                     "cited_by_count": 223
#                 },
#                 {
#                     "year": 2020,
#                     "works_count": 15,
#                     "cited_by_count": 115
#                 },
#                 {
#                     "year": 2019,
#                     "works_count": 12,
#                     "cited_by_count": 63
#                 },
#                 {
#                     "year": 2018,
#                     "works_count": 20,
#                     "cited_by_count": 35
#                 },
#                 {
#                     "year": 2017,
#                     "works_count": 10,
#                     "cited_by_count": 16
#                 },
#                 {
#                     "year": 2016,
#                     "works_count": 4,
#                     "cited_by_count": 9
#                 },
#                 {
#                     "year": 2015,
#                     "works_count": 5,
#                     "cited_by_count": 5
#                 },
#                 {
#                     "year": 2014,
#                     "works_count": 5,
#                     "cited_by_count": 6
#                 },
#                 {
#                     "year": 2013,
#                     "works_count": 5,
#                     "cited_by_count": 1
#                 },
#                 {
#                     "year": 2012,
#                     "works_count": 2,
#                     "cited_by_count": 1
#                 }
#             ],
#             "roles": [
#                 {
#                     "role": "institution",
#                     "id": "https://openalex.org/I4210130200",
#                     "works_count": 187
#                 }
#             ],
#             "x_concepts": [
#                 {
#                     "id": "https://openalex.org/C41008148",
#                     "wikidata": "https://www.wikidata.org/wiki/Q21198",
#                     "display_name": "Computer science",
#                     "level": 0,
#                     "score": 88.2
#                 },
#                 {
#                     "id": "https://openalex.org/C127413603",
#                     "wikidata": "https://www.wikidata.org/wiki/Q11023",
#                     "display_name": "Engineering",
#                     "level": 0,
#                     "score": 53.5
#                 },
#                 {
#                     "id": "https://openalex.org/C86803240",
#                     "wikidata": "https://www.wikidata.org/wiki/Q420",
#                     "display_name": "Biology",
#                     "level": 0,
#                     "score": 50.3
#                 },
#                 {
#                     "id": "https://openalex.org/C162324750",
#                     "wikidata": "https://www.wikidata.org/wiki/Q8134",
#                     "display_name": "Economics",
#                     "level": 0,
#                     "score": 44.4
#                 },
#                 {
#                     "id": "https://openalex.org/C33923547",
#                     "wikidata": "https://www.wikidata.org/wiki/Q395",
#                     "display_name": "Mathematics",
#                     "level": 0,
#                     "score": 43.9
#                 },
#                 {
#                     "id": "https://openalex.org/C154945302",
#                     "wikidata": "https://www.wikidata.org/wiki/Q11660",
#                     "display_name": "Artificial intelligence",
#                     "level": 1,
#                     "score": 41.7
#                 },
#                 {
#                     "id": "https://openalex.org/C17744445",
#                     "wikidata": "https://www.wikidata.org/wiki/Q36442",
#                     "display_name": "Political science",
#                     "level": 0,
#                     "score": 38.5
#                 },
#                 {
#                     "id": "https://openalex.org/C121332964",
#                     "wikidata": "https://www.wikidata.org/wiki/Q413",
#                     "display_name": "Physics",
#                     "level": 0,
#                     "score": 38.5
#                 },
#                 {
#                     "id": "https://openalex.org/C111919701",
#                     "wikidata": "https://www.wikidata.org/wiki/Q9135",
#                     "display_name": "Operating system",
#                     "level": 1,
#                     "score": 35.3
#                 },
#                 {
#                     "id": "https://openalex.org/C205649164",
#                     "wikidata": "https://www.wikidata.org/wiki/Q1071",
#                     "display_name": "Geography",
#                     "level": 0,
#                     "score": 35.3
#                 },
#                 {
#                     "id": "https://openalex.org/C144133560",
#                     "wikidata": "https://www.wikidata.org/wiki/Q4830453",
#                     "display_name": "Business",
#                     "level": 0,
#                     "score": 34.8
#                 },
#                 {
#                     "id": "https://openalex.org/C199539241",
#                     "wikidata": "https://www.wikidata.org/wiki/Q7748",
#                     "display_name": "Law",
#                     "level": 1,
#                     "score": 34.8
#                 },
#                 {
#                     "id": "https://openalex.org/C138885662",
#                     "wikidata": "https://www.wikidata.org/wiki/Q5891",
#                     "display_name": "Philosophy",
#                     "level": 0,
#                     "score": 33.7
#                 },
#                 {
#                     "id": "https://openalex.org/C71924100",
#                     "wikidata": "https://www.wikidata.org/wiki/Q11190",
#                     "display_name": "Medicine",
#                     "level": 0,
#                     "score": 30.5
#                 },
#                 {
#                     "id": "https://openalex.org/C15744967",
#                     "wikidata": "https://www.wikidata.org/wiki/Q9418",
#                     "display_name": "Psychology",
#                     "level": 0,
#                     "score": 27.3
#                 },
#                 {
#                     "id": "https://openalex.org/C105795698",
#                     "wikidata": "https://www.wikidata.org/wiki/Q12483",
#                     "display_name": "Statistics",
#                     "level": 1,
#                     "score": 27.3
#                 },
#                 {
#                     "id": "https://openalex.org/C38652104",
#                     "wikidata": "https://www.wikidata.org/wiki/Q3510521",
#                     "display_name": "Computer security",
#                     "level": 1,
#                     "score": 26.2
#                 },
#                 {
#                     "id": "https://openalex.org/C62520636",
#                     "wikidata": "https://www.wikidata.org/wiki/Q944",
#                     "display_name": "Quantum mechanics",
#                     "level": 1,
#                     "score": 25.7
#                 },
#                 {
#                     "id": "https://openalex.org/C119857082",
#                     "wikidata": "https://www.wikidata.org/wiki/Q2539",
#                     "display_name": "Machine learning",
#                     "level": 1,
#                     "score": 25.1
#                 },
#                 {
#                     "id": "https://openalex.org/C127313418",
#                     "wikidata": "https://www.wikidata.org/wiki/Q1069",
#                     "display_name": "Geology",
#                     "level": 0,
#                     "score": 24.6
#                 },
#                 {
#                     "id": "https://openalex.org/C18903297",
#                     "wikidata": "https://www.wikidata.org/wiki/Q7150",
#                     "display_name": "Ecology",
#                     "level": 1,
#                     "score": 24.1
#                 },
#                 {
#                     "id": "https://openalex.org/C199360897",
#                     "wikidata": "https://www.wikidata.org/wiki/Q9143",
#                     "display_name": "Programming language",
#                     "level": 1,
#                     "score": 24.1
#                 },
#                 {
#                     "id": "https://openalex.org/C31258907",
#                     "wikidata": "https://www.wikidata.org/wiki/Q1301371",
#                     "display_name": "Computer network",
#                     "level": 1,
#                     "score": 23.5
#                 },
#                 {
#                     "id": "https://openalex.org/C76155785",
#                     "wikidata": "https://www.wikidata.org/wiki/Q418",
#                     "display_name": "Telecommunications",
#                     "level": 1,
#                     "score": 22.5
#                 },
#                 {
#                     "id": "https://openalex.org/C119599485",
#                     "wikidata": "https://www.wikidata.org/wiki/Q43035",
#                     "display_name": "Electrical engineering",
#                     "level": 1,
#                     "score": 21.4
#                 }
#             ],
#             "works_api_url": "https://api.openalex.org/works?filter=institutions.id:I4210130200",
#             "updated_date": "2024-03-13T10:04:05.229023",
#             "created_date": "2022-02-02"
#         }
#     ],
#     "group_by": []
# }

# %% [markdown]
# Now we can study what we get, and extract some data. In this json file at the top, you see there are 4 results. That is because we have several campuses: Rwanda, Silicon Valley, Qatar, and the Pittsburgh campus (as you will soon see, there seems to be an Australia campus?).
#
# For each result, there is a subsection of data available. For now, let us focus on the "works_count" and "cited_by_count" data. These are the total number of publications and citations for each campus.

# %% [markdown]
# # jq - shell command to parse json files
#
# jq (https://stedolan.github.io/jq/) is a command-line json processor. It can be used to extract data from json files. The command generally works like this:
#
#     jq query-string json-file
#
# where the query-string is a specialized language used by the tool to get data from the file. This language is sophisticated, and we will only cover enough to meet our needs. Libraries like Python are much more flexible, and for complex queries, it is often better to switch to them. We do that in the next class. The query-string is often a "path" to the data you want. For example, we can get the count in the meta section like this:

# %%
! jq ".meta.count" cmu.json
# Out:
# 4

# %% [markdown]
#
# We can loop over the results to extract subsets of information. Here, for each result we create a new json object containing the display name, works_count and cited_by_count.

# %%
! jq '.results[] | {name: .display_name, count: .works_count, cites: .cited_by_count}' cmu.json
# Out:
# {
#   "name": "Carnegie Mellon University",
#   "count": 121653,
#   "cites": 4962826
# }
# {
#   "name": "Carnegie Mellon University Qatar",
#   "count": 695,
#   "cites": 9705
# }
# {
#   "name": "Carnegie Mellon University Australia",
#   "count": 100,
#   "cites": 2188
# }
# {
#   "name": "Carnegie Mellon University Africa",
#   "count": 186,
#   "cites": 1153
# }

# %% [markdown]
#
#
# You may want to redirect that into a file for subsequent analysis.

# %% [markdown]
# It is moderately tedious to get reasonable displays with jq in the shell. Here we extract the data that we want in one query, and pipe it to a second query that builds up a string. Python is definitely more convenient for this, but we will work with this for now.

# %%
! jq '.results[] | {name: .display_name, count: .works_count, cites: .cited_by_count}' cmu.json | jq '(.name) + ": documents (" + (.count | tostring) + ") citations (" + (.cites | tostring) + ")"'
# Out:
# "Carnegie Mellon University: documents (121847) citations (4971789)"
# "Carnegie Mellon University Qatar: documents (697) citations (9734)"
# "Carnegie Mellon University Australia: documents (93) citations (2191)"
# "Carnegie Mellon University Africa: documents (187) citations (1168)"

# %% [markdown]
# # Writing a shell script
#
# It is tedious to write those commands over and over. We can avoid that by capturing the commands in a shell script. Let's review what needs to happen for that.
#
# 1. we need to create the file where the shell commands will be put.
# 2. The file needs to be executable (chmod +x fname)
# 3. Then we can run the file in our shell.
#
# We will start with a few new concepts first. We will want the script to take some arguments. In our script, we refer to arguments by *$n*. Here is a short script that simply echos the arguments you provide it. Create this file (myscript.sh), make it executable, and try it in the terminal with some arguments.
#
# ```
#     #!/bin/bash
#     echo "arg1 = " $1
#     echo "arg2 = " $2
# ```
#
# Note this script does not have very sophisticated error checking, e.g. for too few or too many arguments. We will not address that here; it is much easier in Python.
#
# The next cell writes this [script](./myscript.sh).

# %%
# %%writefile myscript.sh
# #!/bin/bash
# echo "arg1 = " $1
# echo "arg2 = " $2
# echo $1 "," $2
# Out:
# Overwriting myscript.sh

# %%
! ./myscript.sh
# Out:
# arg1 =
# arg2 =
# ,

# %%
! ls -l myscript.sh
# Out:
# -rwxr-xr-x 1 jupyter-jkitchin@andrew.cm-11dd7 jupyter-jkitchin@andrew.cm-11dd7 63 Mar 13 18:52 myscript.sh

# %%
! chmod +x myscript.sh

# %%
! ./myscript.sh arg1
# Out:
# arg1 =  arg1
# arg2 =
# arg1 ,

# %%
! ./myscript.sh arg1 arg2
# Out:
# arg1 =  arg1
# arg2 =  arg2
# arg1 , arg2

# %%
! ./myscript.sh arg1 arg2 arg3
# Out:
# arg1 =  arg1
# arg2 =  arg2
# arg1 , arg2

# %% [markdown]
# ## OpenAlex institutions script
#
# Now we can create a short script with our code. We will use one argument, the institution to query. It is moderately tedious (IMO) to convert a free form query from the arguments. One option is that you require the user to enter only one argument with no spaces, and + where words should be joined.
#
# I use some bash scripting tricks here. First we assign the query variable to the first argument (this is the first word). Then the `shift 1` line moves the position from the first arg to the next one. We loop over the remaining arguments in the for loop. The special variable $@ holds the rest of these, and we concatenate each word onto the query with a +. Then, we put the query into the curl command. Make this file, e.g. oa-inst.sh, make it executable, and then test it with some examples.
#
# See the script [here](./oa-inst.sh).

# %%
# %%writefile oa-inst.sh
# #!/bin/bash
# query=$1
# shift 1
# for word in "$@"; do
#     query+="+$word"
# done
#
# curl -s https://api.openalex.org/institutions?search=$query | jq '.results[] | {name: .display_name, count: .works_count, cites: .cited_by_count}' | jq '(.name) + ": documents (" + (.count | tostring) + ") citations (" + (.cites | tostring) + ")"'
# Out:
# Writing oa-inst.sh

# %%
! chmod +x oa-inst.sh

# %%
! ./oa-inst.sh "pittsburgh+OR+carnegie"
# Out:
# "University of Pittsburgh: documents (234267) citations (8487215)"
# "Carnegie Mellon University: documents (121847) citations (4971789)"
# "Carnegie Institution for Science: documents (21782) citations (1239867)"
# "Carnegie Observatories: documents (8872) citations (645004)"
# "Children's Hospital of Pittsburgh: documents (16624) citations (525557)"
# "University of Pittsburgh Medical Center: documents (38289) citations (1265036)"
# "VA Pittsburgh Healthcare System: documents (5765) citations (211211)"
# "UPMC Hillman Cancer Center: documents (13170) citations (634020)"
# "Carnegie Museum of Natural History: documents (1207) citations (34968)"
# "Pittsburgh Supercomputing Center: documents (815) citations (32809)"
# "Carnegie Hall: documents (427) citations (13122)"
# "Carnegie Mellon University Qatar: documents (697) citations (9734)"
# "Greater Pittsburgh Orthopaedic Associates: documents (262) citations (7468)"
# "University of Pittsburgh at Bradford: documents (931) citations (8508)"
# "PPG Industries (United States): documents (1184) citations (13868)"
# "Carnegie Foundation for the Advancement of Teaching: documents (284) citations (10800)"
# "Robert Morris University: documents (2120) citations (20169)"
# "University of Pittsburgh at Johnstown: documents (937) citations (6981)"
# "Pittsburgh Quantum Institute: documents (123) citations (3224)"
# "University of Pittsburgh at Greensburg: documents (472) citations (4514)"
# "Carnegie Endowment for International Peace: documents (510) citations (4146)"
# "University of Pittsburgh at Titusville: documents (157) citations (3150)"
# "Veterans Research Foundation of Pittsburgh: documents (55) citations (3003)"
# "Carnegie Mellon University Australia: documents (93) citations (2191)"
# "Pittsburgh Ear Associates: documents (92) citations (1607)"

# %% [markdown]
# ```{note}
# Shell scripts are very particular about whitespace and punctuation. They are less forgiving than languages like Python.
#
# This example is about the limit of what I would consider in a shell script before switching over to Python. Some reasons to use a shell script include:
#
# 1. Python is not installed.
# 2. You don't want to install Python just for a short script.
# ```

# %% [markdown]
# I try to minimize shell scripting in my work. I think you are almost always better off leveraging what you know in Python, and using Python tools to write code that is easier to document and debug.
#
# Some scenarios I have to use shell scripting:
# 1. Building software. Any time you have to install or compile code, you use shell scripts.
# 2. Cloud services. Any kind of maintenance or setup of cloud services almost always requires command line tools and shell scripting.
#
# Some resources on Shell scripting:
#
# 1. https://www.freecodecamp.org/news/shell-scripting-crash-course-how-to-write-bash-scripts-in-linux/
# 2. https://devhints.io/bash

# %% [markdown]
# # Exercise
#
# Use the single author API ([](https://docs.openalex.org/api-entities/authors/get-a-single-author)) to get a list of works_count and cited_by_count by year for me. Here is the url to the data: [](https://api.openalex.org/authors/https://orcid.org/0000-0003-2625-9232).
#
# For each year, print the works_count and cited_by_count. The output should look like this:
#
# ```
# "2023 1 879"
# "2022 9 3415"
# "2021 7 3213"
# "2020 9 2806"
# "2019 7 2376"
# "2018 5 1849"
# "2017 8 1335"
# "2016 15 1154"
# "2015 14 1006"
# "2014 7 806"
# "2013 8 625"
# "2012 9 485"
# ```
#
# Write a shell script that takes an orcid as a single argument, and prints out this information. You can find some CMU ORCIDs at https://orcid.org/orcid-search/search?institution=carnegie%20mellon%20university. Test your script on some of these.
#
# See a solution in the next cell.

# %%
# %%bash
# curl -s https://api.openalex.org/authors/https://orcid.org/0000-0001-7235-1481 \
# | jq '.counts_by_year[]' \
# | jq '(.year | tostring) + " " + (.works_count | tostring) + " " + (.cited_by_count | tostring)'
# Out:
# "2024 1 57"
# "2023 6 272"
# "2022 5 239"
# "2021 4 308"
# "2020 7 289"
# "2019 4 268"
# "2018 9 356"
# "2017 7 222"
# "2016 5 260"
# "2015 7 219"
# "2014 8 261"
# "2013 8 131"
# "2012 6 150"

# %%
# %%bash
# curl -s https://api.openalex.org/authors/https://orcid.org/0000-0001-7235-1481 \
# | jq '.counts_by_year[]' \
# | jq '(.year | tostring) + " " + (.works_count | tostring) + " " + (.cited_by_count | tostring)'
# Out:
# "2024 1 55"
# "2023 6 272"
# "2022 5 239"
# "2021 4 308"
# "2020 7 289"
# "2019 4 268"
# "2018 9 356"
# "2017 7 222"
# "2016 5 260"
# "2015 7 219"
# "2014 8 261"
# "2013 8 131"
# "2012 6 150"

# %% [markdown]
# **Exercise** Come up with your own idea for a simple shell script and implement it.

# %%
# %%writefile test.py
#!/usr/bin/env python
import json

d = json.loads(input())

for c in d['counts_by_year']:
    if c['works_count']> 6:
        print(f'''"{c['year']} {c['works_count']} {c['cited_by_count']}"''')
# Out:
# Overwriting test.py

# %%
! chmod +x test.py

# %%
# %%bash
# curl -s https://api.openalex.org/authors/https://orcid.org/0000-0001-7235-1481 | ./test.py
# Out:
# "2020 7 289"
# "2018 9 356"
# "2017 7 222"
# "2015 7 219"
# "2014 8 261"
# "2013 8 131"
